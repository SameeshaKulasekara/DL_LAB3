# %% [markdown]
# <a href="https://colab.research.google.com/github/SameeshaKulasekara/DL_LAB3/blob/main/Image_Filtering_(Convolution).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ### Load the image using OpenCV

# %%
im = cv2.imread('/content/sample_data/lenna.png') #change the path as needed

# %%
im.shape
# Out:
# (512, 512, 3)

# %% [markdown]
# ### Convert the RGB image into a grayscale image

# %%
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
im.shape
# Out:
# (512, 512)

# %% [markdown]
# ### Define vertical and horizontal filter kernels

# %%
v_kernel = np.array([
    [-9, 0, 9],
    [-9, 0, 9],
    [-9, 0, 9]
])

# %%
h_kernel = np.array([
    [-2, -1, -2],
    [2, 0, 2],
    [2, 1, 2]
])

# %% [markdown]
# ### Do the filtering

# %%
v_image = cv2.filter2D(im, -2, v_kernel)
h_image = cv2.filter2D(im, -2, h_kernel)

# %% [markdown]
# ### Display results

# %%
plt.imshow(im, cmap='gray')
plt.title('Original Image')

plt.figure()
plt.imshow(v_image, cmap='gray')
plt.title('Vertical Image')

plt.figure()
plt.imshow(h_image, cmap='gray')
plt.title('Horizontal Image')
# Out:
# Text(0.5, 1.0, 'Horizontal Image')
